# %% [markdown]
# <head>
#   <meta name="author" content="Rogério de Oliveira">
#   <meta institution="author" content="Universidade Presbiteriana Mackenzie">
# </head>
#
# <img src="http://meusite.mackenzie.br/rogerio/mackenzie_logo/UPM.2_horizontal_vermelho.jpg" width=300, align="right">
#
# <h1 align=left><font size = 8, style="color:rgb(200,0,0)"><b>Ciência de Dados </b></font></h1>
# <h1 align=left><font size = 5, style="color:rgb(0,0,0)"><b>Paradigmas de Linguagens de
# Programação para Ciência de Dados</b></font></h1>
#
# # 1 Introdução à Programação Python
# Professores: *Diego Nogare* & *Rogério de Oliveira*
#
# <br>
# <br>
#
# ---

# %% [markdown]
# # Exercícios

# %% [markdown]
# Em todos os exercícios execute o código abaixo como a primeira instrução e uma única vez para gerar os valores de `letras` e `lista`.
#
# Todos exercícios possuem várias soluções possíveis, mas não se preocupe com isso. A melhor solução é primeiro, a que funciona para você!

# %%
import random; from random import choices; import string; random.seed(1234)
import numpy as np
letras = choices(string.ascii_lowercase,k=100)
lista = random.sample(range(1, 10000), 1000)
print(np.array(lista).sum() == 5244799) # precisa retornar True!
# Out:
# True

# %% [markdown]
# 1. Dos valores [9887, 3233, 813] quais estão presentes em `lista` e, se presentes, qual o seu índice?

# %%
# seu código
print (lista)

print (9887 in lista)
print (3233 in lista)
print (813 in lista)

print (lista.index(9887) , lista.index(3233))
# Out:
# [8303, 1437, 5194, 5008, 7551, 1086, 9585, 4218, 1197, 6985, 3308, 1660, 6499, 3189, 7530, 8201, 3872, 5919, 3361, 8439, 6901, 2863, 9577, 3331, 4945, 989, 5776, 8755, 2508, 8186, 8996, 7741, 5469, 2273, 2146, 788, 2705, 2375, 8947, 1143, 5330, 2803, 28, 997, 1436, 2430, 3556, 654, 7091, 6414, 5316, 3394, 6246, 4589, 8807, 4990, 6915, 5226, 9466, 2481, 8727, 1522, 4266, 4556, 6722, 6555, 9257, 4535, 8615, 1864, 6150, 4493, 3505, 4874, 9626, 6527, 861, 5727, 7219, 3810, 8037, 2709, 6235, 5045, 41, 1202, 7868, 6472, 4890, 7028, 7858, 3041, 6562, 7831, 2576, 4609, 9692, 6055, 9839, 5677, 3377, 2769, 8502, 9307, 7495, 7774, 464, 7666, 1700, 441, 6007, 7796, 1069, 2295, 9635, 5436, 5717, 4746, 4893, 9553, 5417, 9222, 4814, 9217, 3188, 8343, 4572, 1188, 8750, 9867, 3343, 5565, 8361, 5477, 5261, 7505, 4383, 1392, 8639, 9654, 9545, 8983, 1960, 4019, 4214, 6093, 2246, 465, 6465, 613, 723, 3420, 2537, 5129, 8449, 5824, 7120, 8443
 542, 2081, 4395, 8222, 472, 5654, 8330, 983, 4501, 8483, 741, 6744, 7885, 499, 4725, 2992, 3780, 8028, 9439, 1013, 4827, 3988, 7302, 7520, 2869, 4315, 2642, 6840, 5108, 8557, 157, 4787, 5343, 9745, 3040, 533, 5036, 9931, 8188, 296, 6960, 2662, 7123, 5556, 4700, 1541, 1311, 9454, 6865, 9337, 5496, 8643, 9857, 623, 6690, 7246, 8591, 2994, 6650, 1748, 9101, 8480, 5427, 9628, 8490, 8784, 3115, 1643, 6495, 1471, 5210, 8403, 2055, 5413, 7896, 4294, 1251, 1045, 9875, 7384, 173, 5783, 596, 9711, 3544, 1769, 7306, 9037, 2935, 9395, 680, 4372, 8229, 9496, 5087, 9473, 530, 9386, 5529, 8889, 5616, 3482, 1440, 8497, 3995, 1613, 4912, 276, 1120, 1379, 458, 4876, 9136, 5660, 7065, 9990, 6405, 7467, 1435, 3574, 1290, 5709, 5484, 5780, 6362, 5818, 1558, 512, 2118, 2190, 7392, 5871, 2064, 1580, 1012, 4363, 9318, 2598, 518, 5567, 9179, 8090, 9802, 1348, 8244, 7134, 5900, 294, 6890, 5159, 3146, 8876, 2719, 9413, 3757, 6937, 2806, 7087, 8185, 2289, 6216, 8207, 7800, 9433, 6318, 5001, 9339, 4537, 4256, 2342, 5862, 2154, 4280, 5104, 4839, 2748, 2540, 9888, 9518, 7463, 960, 4283, 6874, 6041, 81 ...
# True
# True
# False
# 877 680

# %% [markdown]
# 2. Quais os dois primeiros valores maiores que 2046 em `lista`?

# %%
# seu código
In [9]:lista = np.array(lista)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-a2ffa910f64f> in <module>()
#       1 # seu código
# ----> 2 In [9]:lista = np.array(lista)
#
# NameError: name 'np' is not defined

# %% [markdown]
# 3. Quais os valores mínimo e máximo em `lista`?

# %%
# seu código
print (min(lista))
print (max(lista))
# Out:
# 4
# 9998

# %% [markdown]
# 4. Quais as 4 letras que mais aparecem em `letras`?
#
# <small> ( Existe várias formas de fazer isso, mas fica aqui a sugestão: se você implementar um dicionário *letra:quantidade* poderá empregar a mesma solução na tarefa de aprofundamento! ) </small>

# %%
# seu código

print (letras)

print (sorted(letra))

frequencia = {}

for letra in letras:
    frequencia[letra] = letras.count(letras)

    print("Dicionario")
    print(frequencia)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-64c6d6de87b4> in <module>()
#       1 # seu código
#       2
# ----> 3 print (letras)
#       4
#       5 print (sorted(letra))
#
# NameError: name 'letras' is not defined

# %% [markdown]
# 5. Qual a soma dos valores pares de `lista`?

# %%
# seu código

print lista
# Out:
#   File "<ipython-input-15-47c24247ef67>", line 3
#     print lista
#               ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(lista)?
